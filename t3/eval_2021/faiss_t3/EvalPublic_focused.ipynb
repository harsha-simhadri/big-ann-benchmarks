# %% [markdown]
# # T3 Benchmarks For The FAISS Baseline and GPU Hardware (Public Query Set, focused config)

# %%
import sys
sys.path.append("../..") # make sure we can import t3eval.py from the toplevel 't3' directory
import t3eval
import importlib
importlib.reload(t3eval)
evaluator = t3eval.Evaluator("FAISS Baseline (focused)", # name of team/algo
                             "./public_focused.csv", # exported data from eval runs
                             "../../baseline2021.json", # baseline constants
                             "../../competition2021.json", # competition constants
                             system_cost=22021.90, # participants must submit and document their system cost
                             verbose=True, # recommended True for debugging
                             is_baseline=True,
                             pending = [] 
                            )
evaluator.eval_all()
evaluator.show_summary(savepath="baseline_focused_summary.png")
# Out:
# baseline metrics {'version': '2021', 'deep-1B': {'recall': [0.942, 2002.49], 'qps': [3422.473, 0.916], 'wspq': [0.0], 'min-recall': 0.9, 'min-qps': 2000, 'min-wspq': 0.0}, 'bigann-1B': {'recall': [0.927, 2058.95], 'qps': [2186.755, 0.905], 'wspq': [0.0], 'min-recall': 0.9, 'min-qps': 2000, 'min-wspq': 0.0}, 'msturing-1B': {'recall': [0.91, 2011.542], 'qps': [2421.856, 0.902], 'wspq': [0.0], 'min-recall': 0.9, 'min-qps': 2000, 'min-wspq': 0.0}, 'msspacev-1B': {'recall': [0.85, 2190.829], 'qps': [1484.217, 0.869], 'wspq': [0.0], 'min-recall': 0.9, 'min-qps': 2000, 'min-wspq': 0.0}, 'text2image-1B': {'recall': [0.86, 2120.635], 'qps': [1510.624, 0.882], 'wspq': [0.0], 'min-recall': 0.85, 'min-qps': 2000, 'min-wspq': 0.0}, 'ssnpp-1B': {'recall': [0.978634, 2907.413803], 'qps': [5572.272416, 0.91018], 'wspq': [0.0], 'min-recall': 0.9, 'min-qps': 2000, 'min-wspq': 0.0}}
# competition constants {'version': '2021', 'kwh_cost': 0.1, 'cost_qps': 100000, 'opex_time': 4}
# Found unique datasets: ['bigann-1B' 'deep-1B' 'ssnpp-1B' 'text2image-1B' 'msturing-1B'
#  'msspacev-1B']
#
# evaluating deep-1B
# qps: [2637.80726434938, 3323.000348834289, 4091.718480125533, 2940.919636185386, 4417.035674087254, 3754.3091090535218, 2368.474088744256, 3572.618384448567, 2175.69671844785]
# recall: [0.93429, 0.92178, 0.90772, 0.92914, 0.90088, 0.91309, 0.93927, 0.9169, 0.94306]
# parameters ['FaissIVFPQ(nprobe=180)', 'FaissIVFPQ(nprobe=140)', 'FaissIVFPQ(nprobe=110)', 'FaissIVFPQ(nprobe=160)', 'FaissIVFPQ(nprobe=100)', 'FaissIVFPQ(nprobe=120)', 'FaissIVFPQ(nprobe=200)', 'FaissIVFPQ(nprobe=128)', 'FaissIVFPQ(nprobe=220)']
# for recall, min_qps= 2000
# qualifiers at min_qps=2000.000000 [(2637.80726434938, 0.93429, 'FaissIVFPQ(nprobe=180)'), (3323.000348834289, 0.92178, 'FaissIVFPQ(nprobe=140)'), (4091.718480125533, 0.90772, 'FaissIVFPQ(nprobe=110)'), (2940.919636185386, 0.92914, 'FaissIVFPQ(nprobe=160)'), (4417.035674087254, 0.90088, 'FaissIVFPQ(nprobe=100)'), (3754.3091090535218, 0.91309, 'FaissIVFPQ(nprobe=120)'), (2368.474088744256, 0.93927, 'FaissIVFPQ(nprobe=200)'), (3572.618384448567, 0.9169, 'FaissIVFPQ(nprobe=128)'), (2175.69671844785, 0.94306, 'FaissIVFPQ(nprobe=220)')]
# Best recall at (2175.69671844785, 0.94306, 'FaissIVFPQ(nprobe=220)') via (2175.69671844785, 0.94306, 'FaissIVFPQ(nprobe=220)')
# for throughput, min_recall= 0.9
# qualifiers at min_recall=0.900000 [(0.93429, 2637.80726434938, 'FaissIVFPQ(nprobe=180)'), (0.92178, 3323.000348834289, 'FaissIVFPQ(nprobe=140)'), (0.90772, 4091.718480125533, 'FaissIVFPQ(nprobe=110)'), (0.92914, 2940.919636185386, 'FaissIVFPQ(nprobe=160)'), (0.90088, 4417.035674087254, 'FaissIVFPQ(nprobe=100)'), (0.91309, 3754.3091090535218, 'FaissIVFPQ(nprobe=120)'), (0.93927, 2368.474088744256, 'FaissIVFPQ(nprobe=200)'), (0.9169, 3572.618384448567, 'FaissIVFPQ(nprobe=128)'), (0.94306, 2175.69671844785, 'FaissIVFPQ(nprobe=220)')]
# Best qps at  (0.90088, 4417.035674087254, 'FaissIVFPQ(nprobe=100)') via (0.94306, 2175.69671844785, 'FaissIVFPQ(nprobe=220)')
# for power, min_qps=2000.000000 min_recall=0.900000
# qualifiers at min_qps=2000.000000 and min_recall=0.900000 [(0.93429, 2637.80726434938, 0.1952660992, 'FaissIVFPQ(nprobe=180)'), (0.92178, 3323.000348834289, 0.154868288, 'FaissIVFPQ(nprobe=140)'), (0.90772, 4091.718480125533, 0.12559187968, 'FaissIVFPQ(nprobe=110)'), (0.92914, 2940.919636185386, 0.1776554645333333, 'FaissIVFPQ(nprobe=160)'), (0.90088, 4417.035674087254, 0.1125810582399999, 'FaissIVFPQ(nprobe=100)'), (0.91309, 3754.3091090535218, 0.131238066, 'FaissIVFPQ(nprobe=120)'), (0.93927, 2368.474088744256, 0.2154299306666666, 'FaissIVFPQ(nprobe=200)'), (0.9169, 3572.618384448567, 0.1397968684, 'FaissIVFPQ(nprobe=128)'), (0.94306, 2175.69671844785, 0.235192064, 'FaissIVFPQ(nprobe=220)')]
# Best power at (0.90088, 4417.035674087254, 0.1125810582399999, 'FaissIVFPQ(nprobe=100)') (0.94306, 2175.69671844785, 0.235192064, 'FaissIVFPQ(nprobe=220)')
# Cost benchmark: 23 systems required at best_qps=4417.035674
# Cost benchmark: capex=506503.700000 at unit_cost=22021.900000
# Cost benchmark: opex_kwh_per_query=0.000000 at best_wspq=0.112581
# Cost benchmark: opex_tot_queries=12614400000000.000000 at opex_time=4.000000
# Cost benchmark: opex=39448.402807
#
# evaluating bigann-1B
# qps: [2188.8582664611845, 2718.628240987046, 3423.5457413043223, 2423.435896446243, 3610.6360215844256, 3086.655963993096, 1987.2666848416843, 2935.658172492763, 1804.682221463896]
# recall: [0.92718, 0.9118, 0.89482, 0.92048, 0.88669, 0.90117, 0.93306, 0.90552, 0.93778]
# parameters ['FaissIVFPQ(nprobe=180)', 'FaissIVFPQ(nprobe=140)', 'FaissIVFPQ(nprobe=110)', 'FaissIVFPQ(nprobe=160)', 'FaissIVFPQ(nprobe=100)', 'FaissIVFPQ(nprobe=120)', 'FaissIVFPQ(nprobe=200)', 'FaissIVFPQ(nprobe=128)', 'FaissIVFPQ(nprobe=220)']
# for recall, min_qps= 2000
# qualifiers at min_qps=2000.000000 [(2188.8582664611845, 0.92718, 'FaissIVFPQ(nprobe=180)'), (2718.628240987046, 0.9118, 'FaissIVFPQ(nprobe=140)'), (3423.5457413043223, 0.89482, 'FaissIVFPQ(nprobe=110)'), (2423.435896446243, 0.92048, 'FaissIVFPQ(nprobe=160)'), (3610.6360215844256, 0.88669, 'FaissIVFPQ(nprobe=100)'), (3086.655963993096, 0.90117, 'FaissIVFPQ(nprobe=120)'), (2935.658172492763, 0.90552, 'FaissIVFPQ(nprobe=128)')]
# Best recall at (2188.8582664611845, 0.92718, 'FaissIVFPQ(nprobe=180)') via (2935.658172492763, 0.90552, 'FaissIVFPQ(nprobe=128)')
# for throughput, min_recall= 0.9
# qualifiers at min_recall=0.900000 [(0.92718, 2188.8582664611845, 'FaissIVFPQ(nprobe=180)'), (0.9118, 2718.628240987046, 'FaissIVFPQ(nprobe=140)'), (0.92048, 2423.435896446243, 'FaissIVFPQ(nprobe=160)'), (0.90117, 3086.655963993096, 'FaissIVFPQ(nprobe=120)'), (0.93306, 1987.2666848416843, 'FaissIVFPQ(nprobe=200)'), (0.90552, 2935.658172492763, 'FaissIVFPQ(nprobe=128)'), (0.93778, 1804.682221463896, 'FaissIVFPQ(nprobe=220)')]
# Best qps at  (0.90117, 3086.655963993096, 'FaissIVFPQ(nprobe=120)') via (0.93778, 1804.682221463896, 'FaissIVFPQ(nprobe=220)')
# for power, min_qps=2000.000000 min_recall=0.900000
# qualifiers at min_qps=2000.000000 and min_recall=0.900000 [(0.92718, 2188.8582664611845, 0.2372115602666666, 'FaissIVFPQ(nprobe=180)'), (0.9118, 2718.628240987046, 0.1859861775999999, 'FaissIVFPQ(nprobe=140)'), (0.92048, 2423.435896446243, 0.2104227669333333, 'FaissIVFPQ(nprobe=160)'), (0.90117, 3086.655963993096, 0.1671225756, 'FaissIVFPQ(nprobe=120)'), (0.90552, 2935.658172492763, 0.1725896533333333, 'FaissIVFPQ(nprobe=128)')]
# Best power at (0.90117, 3086.655963993096, 0.1671225756, 'FaissIVFPQ(nprobe=120)') (0.90552, 2935.658172492763, 0.1725896533333333, 'FaissIVFPQ(nprobe=128)')
# Cost benchmark: 33 systems required at best_qps=3086.655964
# Cost benchmark: capex=726722.700000 at unit_cost=22021.900000
# Cost benchmark: opex_kwh_per_query=0.000000 at best_wspq=0.167123
# Cost benchmark: opex_tot_queries=12614400000000.000000 at opex_time=4.000000
# Cost benchmark: opex=58559.750490
#
# evaluating text2image-1B
# qps: [2139.0449820693298, 2731.7485351246105, 3425.330184348624, 2403.007531530499, 4129.40982900796, 3769.843384876258, 3183.310957028136, 1933.541321323983, 2982.606951580274, 1762.363269283565]
# recall: [0.860736, 0.8424149999999999, 0.8227499999999999, 0.852496, 0.80474, 0.8144640000000001, 0.829979, 0.867813, 0.835399, 0.874036]
# parameters ['FaissIVFPQ(nprobe=180)', 'FaissIVFPQ(nprobe=140)', 'FaissIVFPQ(nprobe=110)', 'FaissIVFPQ(nprobe=160)', 'FaissIVFPQ(nprobe=90)', 'FaissIVFPQ(nprobe=100)', 'FaissIVFPQ(nprobe=120)', 'FaissIVFPQ(nprobe=200)', 'FaissIVFPQ(nprobe=128)', 'FaissIVFPQ(nprobe=220)']
# for recall, min_qps= 2000
# qualifiers at min_qps=2000.000000 [(2139.0449820693298, 0.860736, 'FaissIVFPQ(nprobe=180)'), (2731.7485351246105, 0.8424149999999999, 'FaissIVFPQ(nprobe=140)'), (3425.330184348624, 0.8227499999999999, 'FaissIVFPQ(nprobe=110)'), (2403.007531530499, 0.852496, 'FaissIVFPQ(nprobe=160)'), (4129.40982900796, 0.80474, 'FaissIVFPQ(nprobe=90)'), (3769.843384876258, 0.8144640000000001, 'FaissIVFPQ(nprobe=100)'), (3183.310957028136, 0.829979, 'FaissIVFPQ(nprobe=120)'), (2982.606951580274, 0.835399, 'FaissIVFPQ(nprobe=128)')]
# Best recall at (2139.0449820693298, 0.860736, 'FaissIVFPQ(nprobe=180)') via (2982.606951580274, 0.835399, 'FaissIVFPQ(nprobe=128)')
# for throughput, min_recall= 0.85
# qualifiers at min_recall=0.850000 [(0.860736, 2139.0449820693298, 'FaissIVFPQ(nprobe=180)'), (0.852496, 2403.007531530499, 'FaissIVFPQ(nprobe=160)'), (0.867813, 1933.541321323983, 'FaissIVFPQ(nprobe=200)'), (0.874036, 1762.363269283565, 'FaissIVFPQ(nprobe=220)')]
# Best qps at  (0.852496, 2403.007531530499, 'FaissIVFPQ(nprobe=160)') via (0.874036, 1762.363269283565, 'FaissIVFPQ(nprobe=220)')
# for power, min_qps=2000.000000 min_recall=0.850000
# qualifiers at min_qps=2000.000000 and min_recall=0.850000 [(0.860736, 2139.0449820693298, 0.2417272959999999, 'FaissIVFPQ(nprobe=180)'), (0.852496, 2403.007531530499, 0.2139257702399999, 'FaissIVFPQ(nprobe=160)')]
# Best power at (0.852496, 2403.007531530499, 0.2139257702399999, 'FaissIVFPQ(nprobe=160)') (0.852496, 2403.007531530499, 0.2139257702399999, 'FaissIVFPQ(nprobe=160)')
# Cost benchmark: 42 systems required at best_qps=2403.007532
# Cost benchmark: capex=924919.800000 at unit_cost=22021.900000
# Cost benchmark: opex_kwh_per_query=0.000000 at best_wspq=0.213926
# Cost benchmark: opex_tot_queries=12614400000000.000000 at opex_time=4.000000
# Cost benchmark: opex=74959.589892
#
# evaluating msturing-1B
# qps: [2166.22448298012, 3662.0299275297166, 2359.4845936035667, 1947.990518701734, 2582.280920288013, 2864.935604139569, 3207.3350121044414, 4100.480495729172, 1794.7986107194515, 2007.4971568979652]
# recall: [0.906041, 0.881405, 0.902605, 0.910303, 0.8985960000000001, 0.8938689999999999, 0.8883369999999999, 0.87486, 0.913364, 0.90914]
# parameters ['FaissIVFPQ(nprobe=57)', 'FaissIVFPQ(nprobe=32)', 'FaissIVFPQ(nprobe=52)', 'FaissIVFPQ(nprobe=64)', 'FaissIVFPQ(nprobe=47)', 'FaissIVFPQ(nprobe=42)', 'FaissIVFPQ(nprobe=37)', 'FaissIVFPQ(nprobe=28)', 'FaissIVFPQ(nprobe=70)', 'FaissIVFPQ(nprobe=62)']
# for recall, min_qps= 2000
# qualifiers at min_qps=2000.000000 [(2166.22448298012, 0.906041, 'FaissIVFPQ(nprobe=57)'), (3662.0299275297166, 0.881405, 'FaissIVFPQ(nprobe=32)'), (2359.4845936035667, 0.902605, 'FaissIVFPQ(nprobe=52)'), (2582.280920288013, 0.8985960000000001, 'FaissIVFPQ(nprobe=47)'), (2864.935604139569, 0.8938689999999999, 'FaissIVFPQ(nprobe=42)'), (3207.3350121044414, 0.8883369999999999, 'FaissIVFPQ(nprobe=37)'), (4100.480495729172, 0.87486, 'FaissIVFPQ(nprobe=28)'), (2007.4971568979652, 0.90914, 'FaissIVFPQ(nprobe=62)')]
# Best recall at (2007.4971568979652, 0.90914, 'FaissIVFPQ(nprobe=62)') via (2007.4971568979652, 0.90914, 'FaissIVFPQ(nprobe=62)')
# for throughput, min_recall= 0.9
# qualifiers at min_recall=0.900000 [(0.906041, 2166.22448298012, 'FaissIVFPQ(nprobe=57)'), (0.902605, 2359.4845936035667, 'FaissIVFPQ(nprobe=52)'), (0.910303, 1947.990518701734, 'FaissIVFPQ(nprobe=64)'), (0.913364, 1794.7986107194515, 'FaissIVFPQ(nprobe=70)'), (0.90914, 2007.4971568979652, 'FaissIVFPQ(nprobe=62)')]
# Best qps at  (0.902605, 2359.4845936035667, 'FaissIVFPQ(nprobe=52)') via (0.90914, 2007.4971568979652, 'FaissIVFPQ(nprobe=62)')
# for power, min_qps=2000.000000 min_recall=0.900000
# qualifiers at min_qps=2000.000000 and min_recall=0.900000 [(0.906041, 2166.22448298012, 0.2212847952, 'FaissIVFPQ(nprobe=57)'), (0.902605, 2359.4845936035667, 0.2037402864, 'FaissIVFPQ(nprobe=52)'), (0.90914, 2007.4971568979652, 0.2389042032, 'FaissIVFPQ(nprobe=62)')]
# Best power at (0.902605, 2359.4845936035667, 0.2037402864, 'FaissIVFPQ(nprobe=52)') (0.90914, 2007.4971568979652, 0.2389042032, 'FaissIVFPQ(nprobe=62)')
# Cost benchmark: 43 systems required at best_qps=2359.484594
# Cost benchmark: capex=946941.700000 at unit_cost=22021.900000
# Cost benchmark: opex_kwh_per_query=0.000000 at best_wspq=0.203740
# Cost benchmark: opex_tot_queries=12614400000000.000000 at opex_time=4.000000
# Cost benchmark: opex=71390.596355
#
# evaluating msspacev-1B
# qps: [35924.19355907454, 2770.8483394735745, 4985.891689397659, 1508.2260309223818, 23333.10993298764, 14153.527758753222, 421.4765828351125, 8736.147912898428, 801.4524257216032]
# recall: [0.6258698321735572, 0.926865875289944, 0.899116523400191, 0.9478714695047072, 0.7312491472233592, 0.8085618774730522, 0.97378223495702, 0.8605573748123891, 0.963088415882112]
# parameters ['FaissIVFPQ(nprobe=1)', 'FaissIVFPQ(nprobe=32)', 'FaissIVFPQ(nprobe=16)', 'FaissIVFPQ(nprobe=64)', 'FaissIVFPQ(nprobe=2)', 'FaissIVFPQ(nprobe=4)', 'FaissIVFPQ(nprobe=256)', 'FaissIVFPQ(nprobe=8)', 'FaissIVFPQ(nprobe=128)']
# for recall, min_qps= 2000
# qualifiers at min_qps=2000.000000 [(35924.19355907454, 0.6258698321735572, 'FaissIVFPQ(nprobe=1)'), (2770.8483394735745, 0.926865875289944, 'FaissIVFPQ(nprobe=32)'), (4985.891689397659, 0.899116523400191, 'FaissIVFPQ(nprobe=16)'), (23333.10993298764, 0.7312491472233592, 'FaissIVFPQ(nprobe=2)'), (14153.527758753222, 0.8085618774730522, 'FaissIVFPQ(nprobe=4)'), (8736.147912898428, 0.8605573748123891, 'FaissIVFPQ(nprobe=8)')]
# Best recall at (2770.8483394735745, 0.926865875289944, 'FaissIVFPQ(nprobe=32)') via (8736.147912898428, 0.8605573748123891, 'FaissIVFPQ(nprobe=8)')
# for throughput, min_recall= 0.9
# qualifiers at min_recall=0.900000 [(0.926865875289944, 2770.8483394735745, 'FaissIVFPQ(nprobe=32)'), (0.9478714695047072, 1508.2260309223818, 'FaissIVFPQ(nprobe=64)'), (0.97378223495702, 421.4765828351125, 'FaissIVFPQ(nprobe=256)'), (0.963088415882112, 801.4524257216032, 'FaissIVFPQ(nprobe=128)')]
# Best qps at  (0.926865875289944, 2770.8483394735745, 'FaissIVFPQ(nprobe=32)') via (0.963088415882112, 801.4524257216032, 'FaissIVFPQ(nprobe=128)')
# for power, min_qps=2000.000000 min_recall=0.900000
# qualifiers at min_qps=2000.000000 and min_recall=0.900000 [(0.926865875289944, 2770.8483394735745, 0.1673816848137535, 'FaissIVFPQ(nprobe=32)')]
# Best power at (0.926865875289944, 2770.8483394735745, 0.1673816848137535, 'FaissIVFPQ(nprobe=32)') (0.926865875289944, 2770.8483394735745, 0.1673816848137535, 'FaissIVFPQ(nprobe=32)')
# Cost benchmark: 37 systems required at best_qps=2770.848339
# Cost benchmark: capex=814810.300000 at unit_cost=22021.900000
# Cost benchmark: opex_kwh_per_query=0.000000 at best_wspq=0.167382
# Cost benchmark: opex_tot_queries=12614400000000.000000 at opex_time=4.000000
# Cost benchmark: opex=58650.542359
#
# evaluating ssnpp-1B
# qps: [21448.419165621854, 2907.4138031617504, 5572.2724159068, 1512.0612464288613, 20147.778092680743, 19170.02898651143, 410.2332045660885, 10597.289316889975, 788.1118239024763]
# recall: [0.4389192507292648, 0.9786342124385736, 0.9101796143171742, 0.9933828331481498, 0.5512583585149151, 0.6720918026169443, 0.9962095459796412, 0.7931162592665035, 0.9951615301931844]
# parameters ['FaissIVFPQ(nprobe=1)', 'FaissIVFPQ(nprobe=32)', 'FaissIVFPQ(nprobe=16)', 'FaissIVFPQ(nprobe=64)', 'FaissIVFPQ(nprobe=2)', 'FaissIVFPQ(nprobe=4)', 'FaissIVFPQ(nprobe=256)', 'FaissIVFPQ(nprobe=8)', 'FaissIVFPQ(nprobe=128)']
# for recall, min_qps= 2000
# qualifiers at min_qps=2000.000000 [(21448.419165621854, 0.4389192507292648, 'FaissIVFPQ(nprobe=1)'), (2907.4138031617504, 0.9786342124385736, 'FaissIVFPQ(nprobe=32)'), (5572.2724159068, 0.9101796143171742, 'FaissIVFPQ(nprobe=16)'), (20147.778092680743, 0.5512583585149151, 'FaissIVFPQ(nprobe=2)'), (19170.02898651143, 0.6720918026169443, 'FaissIVFPQ(nprobe=4)'), (10597.289316889975, 0.7931162592665035, 'FaissIVFPQ(nprobe=8)')]
# Best recall at (2907.4138031617504, 0.9786342124385736, 'FaissIVFPQ(nprobe=32)') via (10597.289316889975, 0.7931162592665035, 'FaissIVFPQ(nprobe=8)')
# for throughput, min_recall= 0.9
# qualifiers at min_recall=0.900000 [(0.9786342124385736, 2907.4138031617504, 'FaissIVFPQ(nprobe=32)'), (0.9101796143171742, 5572.2724159068, 'FaissIVFPQ(nprobe=16)'), (0.9933828331481498, 1512.0612464288613, 'FaissIVFPQ(nprobe=64)'), (0.9962095459796412, 410.2332045660885, 'FaissIVFPQ(nprobe=256)'), (0.9951615301931844, 788.1118239024763, 'FaissIVFPQ(nprobe=128)')]
# Best qps at  (0.9101796143171742, 5572.2724159068, 'FaissIVFPQ(nprobe=16)') via (0.9951615301931844, 788.1118239024763, 'FaissIVFPQ(nprobe=128)')
# for power, min_qps=2000.000000 min_recall=0.900000
# qualifiers at min_qps=2000.000000 and min_recall=0.900000 [(0.9786342124385736, 2907.4138031617504, 0.17626997248, 'FaissIVFPQ(nprobe=32)'), (0.9101796143171742, 5572.2724159068, 0.09486485184, 'FaissIVFPQ(nprobe=16)')]
# Best power at (0.9101796143171742, 5572.2724159068, 0.09486485184, 'FaissIVFPQ(nprobe=16)') (0.9101796143171742, 5572.2724159068, 0.09486485184, 'FaissIVFPQ(nprobe=16)')
# Cost benchmark: 18 systems required at best_qps=5572.272416
# Cost benchmark: capex=396394.200000 at unit_cost=22021.900000
# Cost benchmark: opex_kwh_per_query=0.000000 at best_wspq=0.094865
# Cost benchmark: opex_tot_queries=12614400000000.000000 at opex_time=4.000000
# Cost benchmark: opex=33240.644085
# This submission has qualified for the competition.
# summary {'deep-1B': [0.94306, 4417.035674087254, 0.1125810582399999, 545952.102807296], 'bigann-1B': [0.92718, 3086.655963993096, 0.1671225756, 785282.45049024], 'text2image-1B': [0.860736, 2403.007531530499, 0.2139257702399999, 999879.389892096], 'msturing-1B': [0.90914, 2359.4845936035667, 0.2037402864, 1018332.2963545601], 'msspacev-1B': [0.926865875289944, 2770.8483394735745, 0.1673816848137535, 873460.8423587392], 'ssnpp-1B': [0.9786342124385736, 5572.2724159068, 0.09486485184, 429634.844084736], 'ranking-score': [0.0, 0.0, 0.0, 0.0]}
#                  recall          qps     power          cost
# deep-1B        0.943060  4417.035674  0.112581  5.459521e+05
# bigann-1B      0.927180  3086.655964  0.167123  7.852825e+05
# text2image-1B  0.860736  2403.007532  0.213926  9.998794e+05
# msturing-1B    0.909140  2359.484594  0.203740  1.018332e+06
# msspacev-1B    0.926866  2770.848339  0.167382  8.734608e+05
# ssnpp-1B       0.978634  5572.272416  0.094865  4.296348e+05
# ranking-score  0.000000     0.000000  0.000000  0.000000e+00
# <b>BigANN Benchmarks Competition Summary For 'FAISS Baseline (focused)'</b><br><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>recall</th>
#       <th>qps</th>
#       <th>power</th>
#       <th>cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>deep-1B</th>
#       <td>0.943060</td>
#       <td>4417.035674</td>
#       <td>0.112581</td>
#       <td>545,952.10</td>
#     </tr>
#     <tr>
#       <th>bigann-1B</th>
#       <td>0.927180</td>
#       <td>3086.655964</td>
#       <td>0.167123</td>
#       <td>785,282.45</td>
#     </tr>
#     <tr>
#       <th>text2image-1B</th>
#       <td>0.860736</td>
#       <td>2403.007532</td>
#       <td>0.213926</td>
#       <td>999,879.39</td>
#     </tr>
#     <tr>
#       <th>msturing-1B</th>
#       <td>0.909140</td>
#       <td>2359.484594</td>
#       <td>0.203740</td>
#       <td>1,018,332.30</td>
#     </tr>
#     <tr>
#       <th>msspacev-1B</th>
#       <td>0.926866</td>
#       <td>2770.848339</td>
#       <td>0.167382</td>
#       <td>873,460.84</td>
#     </tr>
#     <tr>
#       <th>ssnpp-1B</th>
#       <td>0.978634</td>
#       <td>5572.272416</td>
#       <td>0.094865</td>
#       <td>429,634.84</td>
#     </tr>
#     <tr>
#       <th>ranking-score</th>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.00</td>
#     </tr>
#   </tbody>
# </table>
# [1113/050958.260518:WARNING:headless_browser_main_parts.cc(83)] Cannot create Pref Service with no user data dir.
# [1113/050958.279822:ERROR:gpu_init.cc(426)] Passthrough is not supported, GL is egl
# saved summary image at baseline_focused_summary.png
# [1113/050958.503247:INFO:headless_shell.cc(620)] Written to file /tmp/tmpd4ucldyz/temp.png.

# %% [markdown]
# ## Deep1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("deep-1B", 
        zoom=[[1000,5000],[0.90, 0.99]], # provide zoom subplot extents
        tweak=[[700,0],[-1000,0.01]], # adjust text annotation
        savepath="baseline_focused_deep-1B_recall.png"
)
# Out:
# BEST RECALL (2175.69671844785, 0.94306, 'FaissIVFPQ(nprobe=220)')
# saving image to baseline_focused_deep-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("deep-1B", 
        zoom=[[0.85, 0.93],[3000,5000]], # provide zoom subplot extents
        tweak=[[0.01,-200],[-0.03,300]], # adjust text annotation
        savepath="baseline_focused_deep-1B_throughput.png"
)
# Out:
# BEST QPS (0.90088, 4417.035674087254, 'FaissIVFPQ(nprobe=100)')
# saving image to baseline_focused_deep-1B_throughput.png

# %%
# %matplotlib inline
evaluator.plot_power("deep-1B", 
        tweak=[[0.017,0.02],[-2000,0.02]], # adjust text annotation
        savepath="baseline_focused_deep-1B_power.png"
)
# Out:
# BEST POWER (0.90088, 4417.035674087254, 0.1125810582399999, 'FaissIVFPQ(nprobe=100)')
# saving image to baseline_focused_deep-1B_power.png

# %% [markdown]
# ## Bigann-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("bigann-1B", 
        zoom=[[0,5000],[0.90, 1.0]], # provide zoom subplot extents
        tweak=[[200,0],[-1000,0.02]], # adjust text annotation
        savepath="baseline_focused_bigann-1B_recall.png"
)
# Out:
# BEST RECALL (2188.8582664611845, 0.92718, 'FaissIVFPQ(nprobe=180)')
# saving image to baseline_focused_bigann-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("bigann-1B", 
        zoom=[[0.8, 0.99],[1000,4000]], # provide zoom subplot extents
        tweak=[[0.0,200],[-0.04,200]], # adjust text annotation
        savepath="baseline_focused_bigann-1B_throughput.png"
)
# Out:
# BEST QPS (0.90117, 3086.655963993096, 'FaissIVFPQ(nprobe=120)')
# saving image to baseline_focused_bigann-1B_throughput.png

# %%
# %matplotlib inline
evaluator.plot_power("bigann-1B", 
        tweak=[[-0.01,0.01],[-1000,0.01]], # adjust text annotation
        savepath="baseline_focused_bigann-1B_power.png"
)
# Out:
# BEST POWER (0.90117, 3086.655963993096, 0.1671225756, 'FaissIVFPQ(nprobe=120)')
# saving image to baseline_focused_bigann-1B_power.png

# %% [markdown]
# ## Text2Image-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("text2image-1B", 
        zoom=[[2000,3000],[0.84, 0.9]], # provide zoom subplot extents
        tweak=[[500,0.0],[-0,0.01]], # adjust text annotation
        savepath="baseline_focused_text2image-1B_recall.png"
)
# Out:
# BEST RECALL (2139.0449820693298, 0.860736, 'FaissIVFPQ(nprobe=180)')
# saving image to baseline_focused_text2image-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("text2image-1B", 
        zoom=None, #[[0.99,1.0],[4000, 6000]], # provide zoom subplot extents
        tweak=[[-0.05,500],[-0.04,1000]], # adjust text annotation
        savepath="baseline_focused_text2image-1B_throughput.png"
)
# Out:
# BEST QPS (0.852496, 2403.007531530499, 'FaissIVFPQ(nprobe=160)')
# saving image to baseline_focused_text2image-1B_throughput.png

# %%
# %matplotlib inline
evaluator.plot_power("text2image-1B", 
        tweak=[[-0.05,-0.02],[-500,-0.02]], # adjust text annotation
        savepath="baseline_focused_text2image-1B_power.png"
)
# Out:
# BEST POWER (0.852496, 2403.007531530499, 0.2139257702399999, 'FaissIVFPQ(nprobe=160)')
# saving image to baseline_focused_text2image-1B_power.png

# %% [markdown]
# ## Msspacev-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("msspacev-1B", 
        zoom=[[0,5000],[0.85, 0.99]], # provide zoom subplot extents
        tweak=[[1000,0],[-1000,0.02]], # adjust text annotation
        savepath="baseline_focused_msspacev-1B_recall.png"
)
# Out:
# BEST RECALL (2770.8483394735745, 0.926865875289944, 'FaissIVFPQ(nprobe=32)')
# saving image to baseline_focused_msspacev-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("msspacev-1B", 
        zoom=[[0.90, 0.99],[0,5000],], # provide zoom subplot extents
        tweak=[[-0.20,2000],[-0.0,1000]], # adjust text annotation
        savepath="baseline_focused_msspacev-1B_throughput.png"
)
# Out:
# BEST QPS (0.926865875289944, 2770.8483394735745, 'FaissIVFPQ(nprobe=32)')
# saving image to baseline_focused_msspacev-1B_throughput.png

# %%
# %matplotlib inline
evaluator.plot_power("msspacev-1B", 
        tweak=[[-0.25,0.05],[-3000,0.1]], # adjust text annotation
        savepath="baseline_focused_msspacev-1B_poweer.png"
)
# Out:
# BEST POWER (0.926865875289944, 2770.8483394735745, 0.1673816848137535, 'FaissIVFPQ(nprobe=32)')
# saving image to baseline_focused_msspacev-1B_poweer.png

# %% [markdown]
# ## Msturing-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("msturing-1B", 
        zoom=[[0,10000],[0.88, 0.92]], # provide zoom subplot extents
        tweak=[[500,0],[200,0.005]], # adjust text annotation
        savepath="baseline_focused_msturing-1B_recall.png"
)
# Out:
# BEST RECALL (2007.4971568979652, 0.90914, 'FaissIVFPQ(nprobe=62)')
# saving image to baseline_focused_msturing-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("msturing-1B", 
        zoom=[[0.875,0.925],[2000, 3000]], # provide zoom subplot extents
        tweak=[[-0.025,300],[-0.01,100]], # adjust text annotation
        savepath="baseline_focused_msturing-1B_throughput.png"
)
# Out:
# BEST QPS (0.902605, 2359.4845936035667, 'FaissIVFPQ(nprobe=52)')
# saving image to baseline_focused_msturing-1B_throughput.png

# %%
# %matplotlib inline
evaluator.plot_power("msturing-1B", 
        tweak=[[-0.02,0.02],[0,0.02]], # adjust text annotation
        savepath="baseline_focused_msturing-1B_power.png"
)
# Out:
# BEST POWER (0.902605, 2359.4845936035667, 0.2037402864, 'FaissIVFPQ(nprobe=52)')
# saving image to baseline_focused_msturing-1B_power.png

# %% [markdown]
# ## Ssnpp-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("ssnpp-1B", 
        zoom=[[0,5000],[0.95, 1.0]], # provide zoom subplot extents
        tweak=[[0,-0.055],[-1000,-0.009]], # adjust text annotation
        savepath="baseline_focused_ssnpp-1B_recall.png"
)
# Out:
# BEST RECALL (2907.4138031617504, 0.9786342124385736, 'FaissIVFPQ(nprobe=32)')
# saving image to baseline_focused_ssnpp-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("ssnpp-1B", 
        zoom=[[0.88,1.0],[0, 6000]], # provide zoom subplot extents
        tweak=[[-0.3,-1000],[-0.025,-500]], # adjust text annotation
        savepath="baseline_focused_ssnpp-1B_throughput.png"
)
# Out:
# BEST QPS (0.9101796143171742, 5572.2724159068, 'FaissIVFPQ(nprobe=16)')
# saving image to baseline_focused_ssnpp-1B_throughput.png

# %%
# %matplotlib inline
evaluator.plot_power("ssnpp-1B", 
        tweak=[[-0.3,0.1],[2000,0.2]], # adjust text annotation
        savepath="baseline_focused_ssnpp-1B_power.png"
)
# Out:
# BEST POWER (0.9101796143171742, 5572.2724159068, 0.09486485184, 'FaissIVFPQ(nprobe=16)')
# saving image to baseline_focused_ssnpp-1B_power.png
