# %% [markdown]
# # T3 Benchmarks For The FAISS Baseline and GPU Hardware (Public Query Set, focused config)

# %%
import sys
sys.path.append("../..") # make sure we can import t3eval.py from the toplevel 't3' directory
import t3eval
import importlib
importlib.reload(t3eval)
evaluator = t3eval.Evaluator("FAISS Baseline (focused)", # name of team/algo
                             "./public_focused2.csv", # exported data from eval runs
                             "../../baseline2021.json", # baseline constants
                             "../../competition2021.json", # competition constants
                             system_cost=22021.90, # participants must submit and document their system cost
                             verbose=True, # recommended True for debugging
                             is_baseline=True,
                             pending = [ "msspacev-1B" ] 
                            )
evaluator.eval_all()
evaluator.show_summary(savepath="baseline_basic_summary.png")
# Out:
# baseline metrics {'deep-1B': {'recall': [0.942, 2002.49], 'qps': [3422.473, 0.916], 'wspq': [0.0], 'min-recall': 0.9, 'min-qps': 2000, 'min-wspq': 0.0}, 'bigann-1B': {'recall': [0.927, 2058.95], 'qps': [2186.755, 0.905], 'wspq': [0.0], 'min-recall': 0.9, 'min-qps': 2000, 'min-wspq': 0.0}, 'msturing-1B': {'recall': [0.91, 2011.542], 'qps': [2421.856, 0.902], 'wspq': [0.0], 'min-recall': 0.9, 'min-qps': 2000, 'min-wspq': 0.0}, 'msspacev-1B': {'recall': [0.85, 2190.829], 'qps': [1484.217, 0.869], 'wspq': [0.0], 'min-recall': 0.85, 'min-qps': 1484.217, 'min-wspq': 0.0}, 'text2image-1B': {'recall': [0.86, 2120.635], 'qps': [1510.624, 0.882], 'wspq': [0.0], 'min-recall': 0.86, 'min-qps': 1510.624, 'min-wspq': 0.0}, 'ssnpp-1B': {'recall': [0.0, 0.0], 'qps': [0.0, 0.0], 'wspq': [0.0], 'min-recall': 0.9, 'min-qps': 2000, 'min-wspq': 0.0}}
# competition constants {'kwh_cost': 0.1, 'cost_qps': 100000, 'opex_time': 4}
# ...

# %% [markdown]
# ## Deep1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("deep-1B", 
        zoom=[[1000,5000],[0.90, 0.99]], # provide zoom subplot extents
        tweak=[[1000,0],[-1200,0.01]], # adjust text annotation
        savepath="baseline_basic_deep-1B_recall.png"
)
# Out:
# BEST RECALL (2175.69671844785, 0.97202, 'FaissIVFPQ(nprobe=220)')
# saving image to baseline_basic_deep-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("deep-1B", 
        zoom=[[0.85, 0.99],[0,5000]], # provide zoom subplot extents
        tweak=[[-0.02,500],[-0.05,-500]], # adjust text annotation
        savepath=None #"baseline_basic_deep-1B_throughput.png"
)
# Out:
# BEST QPS (0.93824, 4417.035674087254, 'FaissIVFPQ(nprobe=100)')

# %%
# %matplotlib inline
evaluator.plot_power("deep-1B", 
        tweak=[[-0.04,0.02],[0.0,0.02]], # adjust text annotation
        savepath="baseline_basic_deep-1B_power.png"
)
# Out:
# BEST POWER (0.93824, 4417.035674087254, 0.1125810582399999, 'FaissIVFPQ(nprobe=100)')
# saving image to baseline_basic_deep-1B_power.png

# %% [markdown]
# ## Bigann-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("bigann-1B", 
        zoom=[[0,5000],[0.90, 1.0]], # provide zoom subplot extents
        tweak=[[500,0],[-1000,0.01]], # adjust text annotation
        savepath="baseline_basic_bigann-1B_recall.png"
)
# Out:
# BEST RECALL (2188.8582664611845, 0.96139, 'FaissIVFPQ(nprobe=180)')
# saving image to baseline_basic_bigann-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("bigann-1B", 
        zoom=[[0.80, 0.99],[0,5000]], # provide zoom subplot extents
        tweak=[[-0.05,400],[-0.04,500]], # adjust text annotation
        savepath=None #"baseline_basic_bigann-1B_throughput.png"
)
# Out:
# BEST QPS (0.92766, 3610.6360215844256, 'FaissIVFPQ(nprobe=100)')

# %%
# %matplotlib inline
evaluator.plot_power("bigann-1B", 
        tweak=[[-0.04,0.01],[200,0.01]], # adjust text annotation
        savepath="baseline_basic_bigann-1B_power.png"
)
# Out:
# BEST POWER (0.92766, 3610.6360215844256, 0.1376656383999999, 'FaissIVFPQ(nprobe=100)')
# saving image to baseline_basic_bigann-1B_power.png

# %% [markdown]
# ## Text2Image-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("text2image-1B", 
        zoom=[[0,5000],[0.8, 0.99]], # provide zoom subplot extents
        tweak=[[1000,0.0],[-1000,0.03]], # adjust text annotation
        savepath="baseline_basic_text2image-1B_recall.png"
)
# Out:
# BEST RECALL (2412.523293340845, 0.999565, 'FaissIVFPQ(nprobe=160)')
# saving image to baseline_basic_text2image-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("text2image-1B", 
        zoom=[[0.8,0.99],[0, 5000]], # provide zoom subplot extents
        tweak=[[-0.0,0],[-0.0,500]], # adjust text annotation
        savepath="baseline_basic_text2image-1B_throughput.png"
)
# Out:
# BEST QPS (0.998219, 5662.206294675066, 'FaissIVFPQ(nprobe=64)')
# saving image to baseline_basic_text2image-1B_throughput.png

# %%
# %matplotlib inline
evaluator.plot_power("text2image-1B", 
        tweak=[[-0.0,-0.1],[-1000,-0.12]], # adjust text annotation
        savepath="baseline_basic_text2image-1B_power.png"
)
# Out:
# BEST POWER (0.998219, 5662.206294675066, 0.0896748799999999, 'FaissIVFPQ(nprobe=64)')
# saving image to baseline_basic_text2image-1B_power.png

# %% [markdown]
# ## Msspacev-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("msspacev-1B", 
        zoom=[[0,5000],[0.85, 0.99]], # provide zoom subplot extents
        tweak=[[1000,0],[0,0.003]], # adjust text annotation
        savepath="baseline_basic_msspacev-1B_recall.png"
)
# Out:
# BEST RECALL (1508.2260309223818, 0.9527425296766272, 'FaissIVFPQ(nprobe=64)')
# saving image to baseline_basic_msspacev-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("msspacev-1B", 
        zoom=[[0.80, 0.99],[0,5000],], # provide zoom subplot extents
        tweak=[[-0.3,0],[-0.005,200]], # adjust text annotation
        savepath="baseline_basic_msspacev-1B_throughput.png"
)
# Out:
# BEST QPS (0.8614988402237685, 8736.147912898428, 'FaissIVFPQ(nprobe=8)')
# saving image to baseline_basic_msspacev-1B_throughput.png

# %%
# %matplotlib inline
evaluator.plot_power("msspacev-1B", 
        tweak=[[-0.25,0.05],[-3000,0.1]], # adjust text annotation
        savepath="baseline_basic_msspacev-1B_poweer.png"
)
# Out:
# BEST POWER (0.8614988402237685, 8736.147912898428, 0.0525939487879201, 'FaissIVFPQ(nprobe=8)')
# saving image to baseline_basic_msspacev-1B_poweer.png

# %% [markdown]
# ## Msturing-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("msturing-1B", 
        zoom=[[0,10000],[0.85, 0.99]], # provide zoom subplot extents
        tweak=[[500,0],[200,0.005]], # adjust text annotation
        savepath="baseline_basic_msturing-1B_recall.png"
)
# Out:
# BEST RECALL (2007.4971568979652, 0.940744, 'FaissIVFPQ(nprobe=62)')
# saving image to baseline_basic_msturing-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("msturing-1B", 
        zoom=[[0.80,0.99],[0, 5000]], # provide zoom subplot extents
        tweak=[[-0.02,300],[-0.045,200]], # adjust text annotation
        savepath="baseline_basic_msturing-1B_throughput.png"
)
# Out:
# BEST QPS (0.909706, 4100.480495729172, 'FaissIVFPQ(nprobe=28)')
# saving image to baseline_basic_msturing-1B_throughput.png

# %%
# %matplotlib inline
evaluator.plot_power("msturing-1B", 
        tweak=[[-0.02,0.02],[0,0.02]], # adjust text annotation
        savepath="baseline_basic_msturing-1B_power.png"
)
# Out:
# BEST POWER (0.909706, 4100.480495729172, 0.1161909216, 'FaissIVFPQ(nprobe=28)')
# saving image to baseline_basic_msturing-1B_power.png

# %% [markdown]
# ## Ssnpp-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("ssnpp-1B", 
        zoom=[[0,5000],[0.95, 1.0]], # provide zoom subplot extents
        tweak=[[0,-0.055],[-1000,-0.009]], # adjust text annotation
        savepath="baseline_basic_ssnpp-1B_recall.png"
)
# Out:
# BEST RECALL (2907.4138031617504, 0.9786342124385736, 'FaissIVFPQ(nprobe=32)')
# saving image to baseline_basic_ssnpp-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("ssnpp-1B", 
        zoom=[[0.88,1.0],[0, 6000]], # provide zoom subplot extents
        tweak=[[-0.3,-1000],[-0.025,-500]], # adjust text annotation
        savepath="baseline_basic_ssnpp-1B_throughput.png"
)
# Out:
# BEST QPS (0.9101796143171742, 5572.2724159068, 'FaissIVFPQ(nprobe=16)')
# saving image to baseline_basic_ssnpp-1B_throughput.png

# %%
# %matplotlib inline
evaluator.plot_power("ssnpp-1B", 
        tweak=[[-0.3,0.1],[2000,0.2]], # adjust text annotation
        savepath="baseline_basic_ssnpp-1B_power.png"
)
# Out:
# BEST POWER (0.9101796143171742, 5572.2724159068, 0.09486485184, 'FaissIVFPQ(nprobe=16)')
# saving image to baseline_basic_ssnpp-1B_power.png
