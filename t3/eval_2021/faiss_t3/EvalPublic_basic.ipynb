# %% [markdown]
# # T3 Benchmarks For The FAISS Baseline and GPU Hardware (Public Query Set, basic config)

# %%
import sys
sys.path.append("../..") # make sure we can import t3eval.py from the toplevel 't3' directory
import t3eval
import importlib
importlib.reload(t3eval)
evaluator = t3eval.Evaluator("FAISS Baseline (basic)", # name of team/algo
                             "./public_basic.csv", # exported data from eval runs
                             "../../baseline2021.json", # baseline constants
                             "../../competition2021.json", # competition constants
                             system_cost=22021.90, # participants must submit and document their system cost
                             verbose=False, # recommended True for debugging
                             is_baseline=True
                            )
evaluator.eval_all()
evaluator.show_summary(savepath="baseline_basic_summary.png")
# Out:
# <b>BigANN Benchmarks Competition Summary For 'FAISS Baseline (basic)'</b><br><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>recall</th>
#       <th>qps</th>
#       <th>power</th>
#       <th>cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>deep-1B</th>
#       <td>0.916550</td>
#       <td>3489.244563</td>
#       <td>0.144298</td>
#       <td>689,197.08</td>
#     </tr>
#     <tr>
#       <th>bigann-1B</th>
#       <td>0.905020</td>
#       <td>2930.283246</td>
#       <td>0.179213</td>
#       <td>833,562.60</td>
#     </tr>
#     <tr>
#       <th>text2image-1B</th>
#       <td>0.999398</td>
#       <td>24275.569440</td>
#       <td>0.026277</td>
#       <td>119,316.92</td>
#     </tr>
#     <tr>
#       <th>msturing-1B</th>
#       <td>0.881249</td>
#       <td>1943.317032</td>
#       <td>0.247463</td>
#       <td>1,231,849.78</td>
#     </tr>
#     <tr>
#       <th>msspacev-1B</th>
#       <td>0.932344</td>
#       <td>4985.250078</td>
#       <td>0.099697</td>
#       <td>497,393.82</td>
#     </tr>
#     <tr>
#       <th>ssnpp-1B</th>
#       <td>0.978634</td>
#       <td>5235.028439</td>
#       <td>0.096327</td>
#       <td>474,190.81</td>
#     </tr>
#     <tr>
#       <th>ranking-score</th>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.00</td>
#     </tr>
#   </tbody>
# </table>
# [1111/031302.219234:WARNING:headless_browser_main_parts.cc(83)] Cannot create Pref Service with no user data dir.
# [1111/031302.237213:ERROR:gpu_init.cc(426)] Passthrough is not supported, GL is egl
# [1111/031302.454460:INFO:headless_shell.cc(620)] Written to file /tmp/tmpjocqqchh/temp.png.

# %% [markdown]
# ## Deep1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("deep-1B", 
        zoom=[[1000,5000],[0.90, 0.99]], # provide zoom subplot extents
        tweak=[[2000,0],[-1200,0.01]], # adjust text annotation
        savepath="baseline_basic_deep-1B_recall.png"
)

# %%
# %matplotlib inline
evaluator.plot_throughput("deep-1B", 
        zoom=[[0.85, 0.99],[0,5000]], # provide zoom subplot extents
        tweak=[[-0.45,500],[-0.05,-500]], # adjust text annotation
        savepath=None #"baseline_basic_deep-1B_throughput.png"
)

# %%
# %matplotlib inline
evaluator.plot_power("deep-1B", 
        tweak=[[-0.4,0.05],[0.0,0.02]], # adjust text annotation
        savepath="baseline_basic_deep-1B_power.png"
)

# %% [markdown]
# ## Bigann-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("bigann-1B", 
        zoom=[[0,5000],[0.90, 1.0]], # provide zoom subplot extents
        tweak=[[1000,0],[-1000,0.01]], # adjust text annotation
        savepath="baseline_basic_bigann-1B_recall.png"
)

# %%
# %matplotlib inline
evaluator.plot_throughput("bigann-1B", 
        zoom=[[0.80, 0.99],[0,5000]], # provide zoom subplot extents
        tweak=[[-0.65,0],[-0.04,500]], # adjust text annotation
        savepath=None #"baseline_basic_bigann-1B_throughput.png"
)

# %%
# %matplotlib inline
evaluator.plot_power("bigann-1B", 
        tweak=[[-0.4,0.1],[-3000,0.1]], # adjust text annotation
        savepath="baseline_basic_bigann-1B_power.png"
)

# %% [markdown]
# ## Text2Image-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("text2image-1B", 
        zoom=[[0,5000],[0.98, 1.0]], # provide zoom subplot extents
        tweak=[[1000,-0.05],[-1000,-0.003]], # adjust text annotation
        savepath="baseline_basic_text2image-1B_recall.png"
)

# %%
# %matplotlib inline
evaluator.plot_throughput("text2image-1B", 
        zoom=[[0.8,0.99],[20000, 30000]], # provide zoom subplot extents
        tweak=[[-0.2,-1500],[-0.05,500]], # adjust text annotation
        savepath="baseline_basic_text2image-1B_throughput.png"
)

# %%
# %matplotlib inline
evaluator.plot_power("text2image-1B", 
        tweak=[[-0.25,0.1],[-15000,0.12]], # adjust text annotation
        savepath="baseline_basic_text2image-1B_power.png"
)

# %% [markdown]
# ## Msspacev-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("msspacev-1B", 
        zoom=[[0,5000],[0.85, 0.99]], # provide zoom subplot extents
        tweak=[[1000,0],[0,0.003]], # adjust text annotation
        savepath="baseline_basic_msspacev-1B_recall.png"
)

# %%
# %matplotlib inline
evaluator.plot_throughput("msspacev-1B", 
        zoom=[[0.85, 0.92],[1000,6000],], # provide zoom subplot extents
        tweak=[[-0.3,0],[-0.005,200]], # adjust text annotation
        savepath="baseline_basic_msspacev-1B_throughput.png"
)

# %%
# %matplotlib inline
evaluator.plot_power("msspacev-1B", 
        tweak=[[-0.25,0.05],[-3000,0.1]], # adjust text annotation
        savepath="baseline_basic_msspacev-1B_poweer.png"
)

# %% [markdown]
# ## Msturing-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("msturing-1B", 
        zoom=[[0,10000],[0.85, 0.99]], # provide zoom subplot extents
        tweak=[[1000,0],[200,0.005]], # adjust text annotation
        savepath="baseline_basic_msturing-1B_recall.png"
)

# %%
# %matplotlib inline
evaluator.plot_throughput("msturing-1B", 
        zoom=[[0.80,0.99],[0, 5000]], # provide zoom subplot extents
        tweak=[[-0.4,0],[-0.045,200]], # adjust text annotation
        savepath="baseline_basic_msturing-1B_throughput.png"
)

# %%
# %matplotlib inline
evaluator.plot_power("msturing-1B", 
        tweak=[[-0.29,0.1],[0,0.1]], # adjust text annotation
        savepath="baseline_basic_msturing-1B_power.png"
)

# %% [markdown]
# ## Ssnpp-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("ssnpp-1B", 
        zoom=[[0,5000],[0.95, 1.0]], # provide zoom subplot extents
        tweak=[[0,-0.055],[-1000,-0.009]], # adjust text annotation
        savepath="baseline_basic_ssnpp-1B_recall.png"
)

# %%
# %matplotlib inline
evaluator.plot_throughput("ssnpp-1B", 
        zoom=[[0.88,1.0],[0, 6000]], # provide zoom subplot extents
        tweak=[[-0.3,-1000],[-0.025,300]], # adjust text annotation
        savepath="baseline_basic_ssnpp-1B_throughput.png"
)

# %%
# %matplotlib inline
evaluator.plot_power("ssnpp-1B", 
        tweak=[[-0.3,0.1],[2000,0.2]], # adjust text annotation
        savepath="baseline_basic_ssnpp-1B_power.png"
)
