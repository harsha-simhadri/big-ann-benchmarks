# %% [markdown]
# # T3 Analysis For The Microsoft DiskANN Algorithm and Dell PowerEdge Hardware (Public Query Set)

# %%
import sys
sys.path.append("../..") # make sure we can import t3eval.py from the toplevel 't3' directory
import t3eval
import importlib
importlib.reload(t3eval)
evaluator = t3eval.Evaluator("Microsoft DiskANN", # name of team/algo
                             comp_path="../../competition2021.json", # competition constants
                             baseline_path="../../baseline2021.json", # baseline constants
                             system_cost=11742, # participants must submit and document their system cost
                             verbose=False, # recommended True for debugging
                             show_baseline_table=True
                            )
evaluator.load_state_from_files("./summary.json","./evals.json")
#evaluator.eval_all()
#evaluator.show_summary(savepath="gemini_summary.png")
# Out:
# ...
# Loaded state from ./summary.json and ./evals.json

# %% [markdown]
# ## Deep1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("deep-1B", 
        zoom=[[2000,3000],[0.98, 1.0]], # provide zoom subplot extents
        tweak=[[500,0],[0,-0.0015]], # adjust text annotation
        savepath="deep-1B_recall.png"
)
# Out:
# saving image to deep-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("deep-1B", 
        zoom=[[0.93, 0.98],[10000,13000]], # provide zoom subplot extents
        tweak=[[-0.0,-500],[-0.0,-500]], # adjust text annotation
        savepath="deep-1B_throughput.png"
)

# %%
# %matplotlib inline
evaluator.plot_power("deep-1B", 
        tweak=[[0.0,0.1],[-5000,0.1]], # adjust text annotation
        savepath="deep-1B_power.png"
)
# Out:
# No power metrics were provided.  This submission probably did not qualify for this benchmark.
# False

# %% [markdown]
# ## Bigann-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("bigann-1B", 
        zoom=[[2000,5000],[0.98, 1.0]], # provide zoom subplot extents
        tweak=[[0,-0.01],[0,-0.0015]], # adjust text annotation
        savepath="bigann-1B_recall.png"
)
# Out:
# saving image to bigann-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("bigann-1B", 
        zoom=[[0.91, 0.94],[17500,20000]], # provide zoom subplot extents
        tweak=[[-0.0,-900],[-0.0,-500]], # adjust text annotation
        savepath="bigann-1B_throughput.png"
)

# %%
# %matplotlib inline
evaluator.plot_power("bigann-1B", 
        tweak=[[0,0.1],[-5000,0.1]], # adjust text annotation
        savepath="bigann-1B_power.png"
)
# Out:
# No power metrics were provided.  This submission probably did not qualify for this benchmark.
# False

# %% [markdown]
# ## Text2Image-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("text2image-1B", 
        zoom=[[1700,2500],[0.97, 1.0]], # provide zoom subplot extents
        tweak=[[-0,0.003],[0,0.-0.003]], # adjust text annotation
        savepath="text2image-1B_recall.png"
)
# Out:
# saving image to text2image-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("text2image-1B", 
        zoom=[[0.90,0.94],[9000, 10000]], # provide zoom subplot extents
        tweak=[[-0.0,-500],[-0.000,-200]], # adjust text annotation
        savepath="text2image-1B_throughput.png"
)

# %%
# %matplotlib inline
evaluator.plot_power("text2image-1B", 
        tweak=[[-0.01, 0.1],[100,0.21]], # adjust text annotation
        savepath="text2image-1B_power.png"
)
# Out:
# No power metrics were provided.  This submission probably did not qualify for this benchmark.
# False

# %% [markdown]
# ## Msspacev-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("msspacev-1B", 
        zoom=[[1000,3000],[0.985, 0.999]], # provide zoom subplot extents
        tweak=[[0,-0.1],[-500, 0.003]], # adjust text annotation
        savepath="msspacev-1B_recall.png"
)
# Out:
# saving image to msspacev-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("msspacev-1B", 
        zoom=[[0.95, 1.0],[6000,8000],], # provide zoom subplot extents
        tweak=[[-0.65,100],[0.006,200]], # adjust text annotation
        savepath="msspacev-1B_throughput.png"
)

# %%
# %matplotlib inline
evaluator.plot_power("msspacev-1B", 
        tweak=[[0,0.05],[-4000,0.1]], # adjust text annotation
        savepath="msspacev-1B_power.png"
)
# Out:
# No power metrics were provided.  This submission probably did not qualify for this benchmark.
# False

# %% [markdown]
# ## Msturing-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("msturing-1B", 
        zoom=[[1000,5000],[0.97, 0.999]], # provide zoom subplot extents
        tweak=[[2000,0],[100,0.00]], # adjust text annotation
        savepath="msturing-1B_recall.png"
)
# Out:
# saving image to msturing-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("msturing-1B", 
        zoom=None, #[[0.88,0.94],[18000, 21000]], # provide zoom subplot extents
        tweak=None, #[[-0.015,-6000],[-0.015,200]], # adjust text annotation
        savepath="msturing-1B_throughput.png"
)

# %%
# %matplotlib inline
evaluator.plot_power("msturing-1B", 
        tweak=[[-0.01,0.1],[-12000,0.1]], # adjust text annotation
        savepath="msturing-1B_power.png"
)

# %% [markdown]
# ## Ssnpp-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("ssnpp-1B", 
        zoom=[[1900,2600],[0.97, 0.99]], # provide zoom subplot extents
        tweak=[[2000,0],[0,-0.009]], # adjust text annotation
        savepath="ssnpp-1B_recall.png"
)
# Out:
# Submission did not qualify for ssnpp-1B on the recall benchmark.
# False

# %%
# %matplotlib inline
evaluator.plot_throughput("ssnpp-1B", 
        zoom=[[8000,10000],[0.87, 0.95]], # provide zoom subplot extents
        tweak=[[-0.01,-2000],[-0.025,300]], # adjust text annotation
        savepath="ssnpp-1B_throughput.png"
)
# Out:
# Submission did not qualify for ssnpp-1B on the throughput benchmark.
# False

# %%
# %matplotlib inline
evaluator.plot_power("ssnpp-1B", 
        tweak=[[0,0.1],[-5000,0.1]], # adjust text annotation
        savepath="ssnpp-1B_power.png"
)
# Out:
# Submission did not qualify for ssnpp-1B on the power and cost benchmark.
# False
