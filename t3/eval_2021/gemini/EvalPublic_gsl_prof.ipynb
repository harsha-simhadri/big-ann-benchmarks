# %% [markdown]
# # T3 Benchmarks For The Gemini Algorithm and Hardware (Public Query Set)

# %%
import sys
sys.path.append("../..") # make sure we can import t3eval.py from the toplevel 't3' directory
import t3eval
import importlib
importlib.reload(t3eval)
evaluator = t3eval.Evaluator("Gemini (gsl_prof)", # name of team/algo
                             "./public_gsl_prof.csv", # exported data from eval runs
                             "../../baseline2021.json", # baseline constants
                             "../../competition2021.json", # competition constants
                             system_cost=55726.26, # participants must submit and document their system cost
                             verbose=False, # recommended True for debugging,
                             print_best=False,
                             show_baseline_table=True
                            )
evaluator.eval_all()
evaluator.show_summary()
# Out:
# evaluating deep-1B
# evaluating bigann-1B
# evaluating msturing-1B
# evaluating msspacev-1B
# evaluating text2image-1B
# evaluating ssnpp-1B
# <b>BigANN Benchmarks Competition Summary For 'Gemini (gsl_prof)'</b><br><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>recall</th>
#       <th>qps</th>
#       <th>power</th>
#       <th>cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>deep-1B</th>
#       <td>0.98871</td>
#       <td>9116.79</td>
#       <td>0.0402418</td>
#       <td>627,089.58</td>
#     </tr>
#     <tr>
#       <th>bigann-1B</th>
#       <td>0.99253</td>
#       <td>9510.5</td>
#       <td>0.0396964</td>
#       <td>626,898.50</td>
#     </tr>
#     <tr>
#       <th>msturing-1B</th>
#       <td>0.977834</td>
#       <td>20039.9</td>
#       <td>0.0231277</td>
#       <td>286,735.24</td>
#     </tr>
#     <tr>
#       <th>msspacev-1B</th>
#       <td>0.986223</td>
#       <td>8516.25</td>
#       <td>0.0523468</td>
#       <td>687,057.44</td>
#     </tr>
#     <tr>
#       <th>text2image-1B</th>
#       <td>0.997259</td>
#       <td>2354.89</td>
#       <td>0.277439</td>
#       <td>2,493,443.66</td>
#     </tr>
#     <tr>
#       <th>ssnpp-1B</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>ranking-score</th>
#       <td>0.453556</td>
#       <td>38512.4</td>
#       <td>0.432851</td>
#       <td>0.43</td>
#     </tr>
#   </tbody>
# </table>
# <b>BigANN Benchmarks Baseline</b><br><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>recall</th>
#       <th>qps</th>
#       <th>power</th>
#       <th>cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>deep-1B</th>
#       <td>0.942000</td>
#       <td>3422.473000</td>
#       <td>0.0</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>bigann-1B</th>
#       <td>0.927000</td>
#       <td>2186.755000</td>
#       <td>0.0</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>msturing-1B</th>
#       <td>0.910000</td>
#       <td>2421.856000</td>
#       <td>0.0</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>msspacev-1B</th>
#       <td>0.850000</td>
#       <td>1484.217000</td>
#       <td>0.0</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>text2image-1B</th>
#       <td>0.860000</td>
#       <td>1510.624000</td>
#       <td>0.0</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>ssnpp-1B</th>
#       <td>0.978634</td>
#       <td>5572.272416</td>
#       <td>0.0</td>
#       <td>0.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Deep1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("deep-1B", 
        zoom=[[1900,2600],[0.97, 0.99]], # provide zoom subplot extents
        tweak=[[2000,0],[0,-0.009]], # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_throughput("deep-1B", 
        zoom=[[0.87, 0.95],[8000,10000]], # provide zoom subplot extents
        tweak=[[-0.01,-2000],[-0.025,300]], # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_power("deep-1B", 
        tweak=[[0.0,0.1],[-5000,0.1]], # adjust text annotation
)

# %% [markdown]
# ## Bigann-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("bigann-1B", 
        zoom=[[1500,3000],[0.97, 1.0]], # provide zoom subplot extents
        tweak=[[2000,0],[0,-0.009]], # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_throughput("bigann-1B", 
        zoom=[[0.87, 0.95],[9000,10000]], # provide zoom subplot extents
        tweak=[[-0.01,-2000],[-0.025,300]], # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_power("bigann-1B", 
        tweak=[[0,0.1],[-5000,0.1]], # adjust text annotation
)

# %% [markdown]
# ## Text2Image-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("text2image-1B", 
        zoom=None, #[[1700,2500],[0.86, 0.90]], # provide zoom subplot extents
        tweak=None #[[0,0.0],[0,0.0]], # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_throughput("text2image-1B", 
        zoom=None, #[[0.86,0.89],[1750, 2400]], # provide zoom subplot extents
        tweak=None #[[0.0,-700],[0.0,-80]], # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_power("text2image-1B", 
        tweak=[[0,0.1],[-1200,0.21]], # adjust text annotation
)

# %% [markdown]
# ## Msspacev-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("msspacev-1B", 
        zoom=None, #[[1500,3600],[0.92, 0.93]], # provide zoom subplot extents
        tweak=None #[[2000,0],[0,0.003]], # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_throughput("msspacev-1B", 
        zoom=None, #[[0.87, 0.95],[8000,9000],], # provide zoom subplot extents
        tweak=None #[[0.005,-500],[-0.005,200]], # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_power("msspacev-1B", 
        tweak=[[0,0.05],[-4000,0.1]], # adjust text annotation
)

# %% [markdown]
# ## Msturing-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("msturing-1B", 
        zoom=[[1200,4000],[0.97, 0.99]], # provide zoom subplot extents
        tweak=[[2000,0],[0,0.005]], # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_throughput("msturing-1B", 
        zoom=[[0.88,0.94],[18000, 21000]], # provide zoom subplot extents
        tweak=[[-0.015,-6000],[-0.015,200]], # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_power("msturing-1B", 
        tweak=[[-0.01,0.1],[-12000,0.1]], # adjust text annotation
)

# %% [markdown]
# ## Ssnpp-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("ssnpp-1B", 
        zoom=[[1900,2600],[0.97, 0.99]], # provide zoom subplot extents
        tweak=[[2000,0],[0,-0.009]], # adjust text annotation
)
# Out:
# Submission did not qualify for ssnpp-1B on the recall benchmark.
# False

# %%
# %matplotlib inline
evaluator.plot_throughput("ssnpp-1B", 
        zoom=[[8000,10000],[0.87, 0.95]], # provide zoom subplot extents
        tweak=[[-0.01,-2000],[-0.025,300]], # adjust text annotation
)
# Out:
# Submission did not qualify for ssnpp-1B on the throughput benchmark.
# False

# %%
# %matplotlib inline
evaluator.plot_power("ssnpp-1B", 
        tweak=[[0,0.1],[-5000,0.1]], # adjust text annotation
)
# Out:
# Submission did not qualify for ssnpp-1B on the power and cost benchmark.
# False
