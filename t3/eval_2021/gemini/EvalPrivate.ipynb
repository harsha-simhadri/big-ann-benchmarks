# %% [markdown]
# # T3 Analysis For The Gemini Algorithm and LedaE APU Hardware (PrivateQuery Set)

# %%
import sys
sys.path.append("../..") # make sure we can import t3eval.py from the toplevel 't3' directory
import t3eval
import importlib
importlib.reload(t3eval)
evaluator = t3eval.Evaluator("Gemini", # name of team/algo
                             comp_path="../../competition2021.json", # competition constants
                             baseline_path="../../private_baseline2021.json", # baseline constants
                             verbose=False, # recommended True for debugging
                             show_baseline_table=True
                            )
evaluator.load_state_from_files("./private_summary.json","./private_evals.json")
#evaluator.eval_all()
#evaluator.show_summary(savepath="gemini_summary.png")
# Out:
# Warning: summary was not empty/none
# Warning: evals was not empty/none
# Loaded state from ./private_summary.json and ./private_evals.json

# %% [markdown]
# ## Deep1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("deep-1B", 
        zoom=[[2000,2500],[0.97, 1.0]], # provide zoom subplot extents
        tweak=[[500,0],[-100,0.005]], # adjust text annotation
        savepath="private_deep-1B_recall.png"
)
# Out:
# Submission did not qualify for deep-1B on the recall benchmark.
# False

# %%
# %matplotlib inline
evaluator.plot_throughput("deep-1B", 
        zoom=[[0.86, 0.95],[8000,13000]], # provide zoom subplot extents
        tweak=[[-0.01,-2000],[-0.025,300]], # adjust text annotation
        savepath="private_deep-1B_throughput.png"
)
# Out:
# Submission did not qualify for deep-1B on the throughput benchmark.
# False

# %%
# %matplotlib inline
evaluator.plot_power("deep-1B", 
        tweak=[[0.0,0.1],[-5000,0.1]], # adjust text annotation
        savepath="private_deep-1B_power.png"
)
# Out:
# Submission did not qualify for deep-1B on the power and cost benchmark.
# False

# %% [markdown]
# ## Bigann-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("bigann-1B", 
        zoom=[[1500,3000],[0.97, 1.0]], # provide zoom subplot extents
        tweak=[[2000,0],[-300,-0.009]], # adjust text annotation
        savepath="private_bigann-1B_recall.png"
)
# Out:
# saving image to private_bigann-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("bigann-1B", 
        zoom=[[0.87, 0.95],[10000,13000]], # provide zoom subplot extents
        tweak=[[-0.01,-2000],[-0.025,300]], # adjust text annotation
        savepath="private_bigann-1B_throughput.png"
)

# %%
# %matplotlib inline
evaluator.plot_power("bigann-1B", 
        tweak=[[0,0.1],[-5000,0.1]], # adjust text annotation
        savepath="private_bigann-1B_power.png"
)
# Out:
# No power metrics were provided.  This submission probably did not qualify for this benchmark.
# False

# %% [markdown]
# ## Text2Image-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("text2image-1B", 
        zoom=[[1500,3000],[0.580, 0.74]], # provide zoom subplot extents
        tweak=[[100,0.001],[-100,0.005]], # adjust text annotation
        savepath="private_text2image-1B_recall.png"
)
# Out:
# saving image to private_text2image-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("text2image-1B", 
        zoom=[[0.60,0.70],[1000, 5000]], # provide zoom subplot extents
        tweak=[[-0.07,-200],[0.01,400]], # adjust text annotation
        savepath="private_text2image-1B_throughput.png"
)

# %%
# %matplotlib inline
evaluator.plot_power("text2image-1B", 
        tweak=[[0.01, 0.05],[-700,0.05]], # adjust text annotation
        savepath="private_text2image-1B_power.png"
)
# Out:
# No power metrics were provided.  This submission probably did not qualify for this benchmark.
# False

# %% [markdown]
# ## Msspacev-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("msspacev-1B", 
        zoom=[[1000,3000],[0.985, 0.999]], # provide zoom subplot extents
        tweak=[[1000,0],[-500, 0.004]], # adjust text annotation
        savepath="msspacev-1B_recall.png"
)
# Out:
# Submission did not qualify for msspacev-1B on the recall benchmark.
# False

# %%
# %matplotlib inline
evaluator.plot_throughput("msspacev-1B", 
        zoom=[[0.88, 0.92],[10000,20000],], # provide zoom subplot extents
        tweak=[[0.005,-500],[-0.008,400]], # adjust text annotation
        savepath="private_msspacev-1B_throughput.png"
)
# Out:
# Submission did not qualify for msspacev-1B on the throughput benchmark.
# False

# %%
# %matplotlib inline
evaluator.plot_power("msspacev-1B", 
        tweak=[[0,0.05],[-12000,0.1]], # adjust text annotation
        savepath="private_msspacev-1B_power.png"
)
# Out:
# Submission did not qualify for msspacev-1B on the power and cost benchmark.
# False

# %% [markdown]
# ## Msturing-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("msturing-1B", 
        zoom=[[1200,4000],[0.97, 0.99]], # provide zoom subplot extents
        tweak=[[2000,0],[0,0.005]], # adjust text annotation
        savepath="private_msturing-1B_recall.png"
)
# Out:
# saving image to private_msturing-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("msturing-1B", 
        zoom=[[0.88,0.94],[12000, 18000]], # provide zoom subplot extents
        tweak=[[-0.013,-6000],[-0.015,200]], # adjust text annotation
        savepath="private_msturing-1B_throughput.png"
)

# %%
# %matplotlib inline
evaluator.plot_power("msturing-1B", 
        tweak=[[-0.01,0.1],[-12000,0.1]], # adjust text annotation
        savepath="private_msturing-1B_power.png"
)
# Out:
# No power metrics were provided.  This submission probably did not qualify for this benchmark.
# False

# %% [markdown]
# ## Ssnpp-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("ssnpp-1B", 
        zoom=[[1900,5000],[0.97, 0.999]], # provide zoom subplot extents
        tweak=[[0,-0.007],[-1000,-0.009]], # adjust text annotation
        savepath="private_ssnpp-1B_recall.png"
)
# Out:
# saving image to private_ssnpp-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("ssnpp-1B", 
        zoom=[[0.93,0.98],[7000, 11000]], # provide zoom subplot extents
        tweak=[[0.01,-500],[-0.01,300]], # adjust text annotation
        savepath="private_ssnpp-1B_throughput.png"
)

# %%
# %matplotlib inline
evaluator.plot_power("ssnpp-1B", 
        tweak=[[0,0.1],[-5000,0.1]], # adjust text annotation
        savepath="private_ssnpp-1B_power.png"
)
# Out:
# No power metrics were provided.  This submission probably did not qualify for this benchmark.
# False
