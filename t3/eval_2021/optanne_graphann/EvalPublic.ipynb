# %% [markdown]
# # T3 Benchmarks For The Gemini Algorithm and Hardware (Public Query Set)

# %%
import sys
sys.path.append("../..") # make sure we can import t3eval.py from the toplevel 't3' directory
import t3eval
import importlib
importlib.reload(t3eval)
evaluator = t3eval.Evaluator("OptANNe GraphANN", # name of team/algo
                             comp_path="../../competition2021.json", # competition constants
                             baseline_path="../../baseline2021.json", # baseline constants
                             system_cost=55726.26, # participants must submit and document their system cost
                             verbose=False, # recommended True for debugging
                             show_baseline_table=True
                            )
evaluator.load_state_from_files("./summary.json","./evals.json")
#evaluator.eval_all()
#evaluator.show_summary(savepath="gemini_summary.png")
# Out:
# Warning: summary was not empty/none
# Warning: evals was not empty/none
# Loaded state from ./summary.json and ./evals.json

# %% [markdown]
# ## Deep1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("deep-1B", 
        zoom=[[10000,50000],[0.97, 0.99]], # provide zoom subplot extents
        tweak=[[14000,0],[-30000,0]], # adjust text annotation
        savepath="deep-1B_recall.png"
)
# Out:
# saving image to deep-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("deep-1B", 
        zoom=[[0.87, 0.93],[180000,200000]], # provide zoom subplot extents
        tweak=[[0.01,0],[-0.01,10000]], # adjust text annotation
        savepath="deep-1B_throughput.png"
)

# %%
# %matplotlib inline
evaluator.plot_power("deep-1B", 
        tweak=[[0.0,0.001],[-70000,0.001]], # adjust text annotation
        savepath="deep-1B_power.png"
)

# %% [markdown]
# ## Bigann-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("bigann-1B", 
        zoom=[[50000,100000],[0.97, 1.0]], # provide zoom subplot extents
        tweak=[[50000,0],[0,0.001]], # adjust text annotation
        savepath="bigann-1B_recall.png"
)
# Out:
# saving image to bigann-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("bigann-1B", 
        zoom=[[0.87, 0.93],[300000,400000]], # provide zoom subplot extents
        tweak=[[0.0,10000],[-0.001,30000]], # adjust text annotation
        savepath="bigann-1B_throughput.png"
)

# %%
# %matplotlib inline
evaluator.plot_power("bigann-1B", 
        tweak=[[0,0.001],[-150000,0.001]], # adjust text annotation
        savepath="bigann-1B_power.png"
)

# %% [markdown]
# ## Text2Image-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("text2image-1B", 
        zoom=[[10000,10700],[0.902, 0.905]], # provide zoom subplot extents
        tweak=[[200,-0.0005],[-400,0.001]], # adjust text annotation
        savepath="text2image-1B_recall.png"
)
# Out:
# saving image to text2image-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("text2image-1B", 
        zoom=[[0.900,0.902],[10700, 11000]], # provide zoom subplot extents
        tweak=[[-0.001,100],[-0.00,100]], # adjust text annotation
        savepath="text2image-1B_throughput.png"
)

# %%
# %matplotlib inline
evaluator.plot_power("text2image-1B", 
        tweak=[[-0.001, 0.001],[-200,0.001]], # adjust text annotation
        savepath="text2image-1B_power.png"
)

# %% [markdown]
# ## Msspacev-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("msspacev-1B", 
        zoom=[[30000,50000],[0.985, 0.999]], # provide zoom subplot extents
        tweak=[[10000,0],[-10000, 0.001]], # adjust text annotation
        savepath="msspacev-1B_recall.png"
)
# Out:
# saving image to msspacev-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("msspacev-1B", 
        zoom=[[0.95, 0.965],[130000,150000],], # provide zoom subplot extents
        tweak=[[0.001,-30000],[-0.005,5000]], # adjust text annotation
        savepath="msspacev-1B_throughput.png"
)

# %%
# %matplotlib inline
evaluator.plot_power("msspacev-1B", 
        tweak=[[0.005,0.004],[-60000,0.002]], # adjust text annotation
        savepath="msspacev-1B_poweer.png"
)

# %% [markdown]
# ## Msturing-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("msturing-1B", 
        zoom=[[40000,60000],[0.96, 0.99]], # provide zoom subplot extents
        tweak=[[-5000,-0.01],[-10000,0.001]], # adjust text annotation
        savepath="msturing-1B_recall.png"
)
# Out:
# saving image to msturing-1B_recall.png

# %%
# %matplotlib inline
evaluator.plot_throughput("msturing-1B", 
        zoom=[[0.88,0.93],[140000, 170000]], # provide zoom subplot extents
        tweak=[[-0.01,-60000],[-0.015,10000]], # adjust text annotation
        savepath="msturing-1B_throughput.png"
)

# %%
# %matplotlib inline
evaluator.plot_power("msturing-1B", 
        tweak=[[-0.01,0.001],[-80000,0.001]], # adjust text annotation
        savepath="msturing-1B_power.png"
)

# %% [markdown]
# ## Ssnpp-1B Analysis

# %%
# %matplotlib inline
evaluator.plot_recall("ssnpp-1B", 
        zoom=None, #[[1900,2600],[0.97, 0.99]], # provide zoom subplot extents
        tweak=None, #[[2000,0],[0,-0.009]], # adjust text annotation
        savepath="ssnpp-1B_recall.png"
)
# Out:
# Submission did not qualify for ssnpp-1B on the recall benchmark.
# False

# %%
# %matplotlib inline
evaluator.plot_throughput("ssnpp-1B", 
        zoom=None, #[[8000,10000],[0.87, 0.95]], # provide zoom subplot extents
        tweak=None, #[[-0.01,-2000],[-0.025,300]], # adjust text annotation
        savepath="ssnpp-1B_throughput.png"
)
# Out:
# Submission did not qualify for ssnpp-1B on the throughput benchmark.
# False

# %%
# %matplotlib inline
evaluator.plot_power("ssnpp-1B", 
        tweak=None, #[[0,0.1],[-5000,0.1]], # adjust text annotation
        savepath="ssnpp-1B_power.png"
)
# Out:
# Submission did not qualify for ssnpp-1B on the power and cost benchmark.
# False
