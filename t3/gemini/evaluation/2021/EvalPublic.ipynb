# %% [markdown]
# # T3 Benchmarks For GSI's Gemini Algorithm and Hardware (Public Query Set)

# %%
import sys
sys.path.append("../../..") # make sure we can import t3eval.py
import t3eval
import importlib
importlib.reload(t3eval)
evaluator = t3eval.Evaluator("./public.csv", "../../../baseline2021.json", verbose=True)
# Out:
# Found unique datasets: ['bigann-1B' 'deep-1B' 'text2image-1B' 'msturing-1B' 'msspacev-1B']
# baseline metrics {'deep-1B': {'recall': [0.942, 2002.49], 'qps': [3422.473, 0.916], 'min-recall': 0.9, 'min-qps': 2000}, 'bigann-1B': {'recall': [0.927, 2058.95], 'qps': [2186.755, 0.905], 'min-recall': 0.9, 'min-qps': 2000}, 'msturing-1B': {'recall': [0.91, 2011.542], 'qps': [2421.856, 0.902], 'min-recall': 0.9, 'min-qps': 2000}, 'msspacev-1B': {'recall': [0.85, 2190.829], 'qps': [1484.217, 0.869], 'min-recall': 0.85, 'min-qps': 1484.217}, 'text2image-1B': {'recall': [0.86, 2120.635], 'qps': [1510.624, 0.882], 'min-recall': 0.86, 'min-qps': 1510.624}}

# %%
evaluator.eval_all()
evaluator.show_summary()
# Out:
# evaluating deep-1B
# qps: [2350.927052332753, 2286.700366428896, 2399.679470914177, 2169.256121136053, 8771.259456547561, 9031.89768725671, 8767.297382773071, 9174.083888444753, 9013.14504374196, 2037.532475374435]
# recall: [0.9847100000000001, 0.98596, 0.9823200000000001, 0.98707, 0.91196, 0.90748, 0.91489, 0.90079, 0.8894500000000001, 0.9877600000000001]
# qualifiers at min_qps=2000.000000 and baseline_recall=0.942000 [(2350.927052332753, 0.9847100000000001), (2286.700366428896, 0.98596), (2399.679470914177, 0.9823200000000001), (2169.256121136053, 0.98707), (2037.532475374435, 0.9877600000000001)]
# Best recall at (2037.532475374435, 0.9877600000000001)
# qualifiers at min_qps=2000.000000 and baseline_recall=0.942000 [(0.91196, 8771.259456547561), (0.90748, 9031.89768725671), (0.91489, 8767.297382773071), (0.90079, 9174.083888444753)]
# Best qps at  (0.90079, 9174.083888444753)
# qualifiers at min_qps=2000.000000 and min_recall=0.900000 [(0.9847100000000001, 2350.927052332753, 0.23875548506666666), (0.98596, 2286.700366428896, 0.2604831770666666), (0.9823200000000001, 2399.679470914177, 0.2289913501333333), (0.98707, 2169.256121136053, 0.29281921173333336), (0.91196, 8771.259456547561, 0.04272975982222222), (0.90748, 9031.89768725671, 0.04169707535999999), (0.91489, 8767.297382773071, 0.04493327182222223), (0.90079, 9174.083888444753, 0.040971066560000005), (0.9877600000000001, 2037.532475374435, 0.2916504069333333)]
# Best power at (0.90079, 9174.083888444753, 0.040971066560000005)
#
# evaluating bigann-1B
# qps: [9495.57346820266, 9438.9391707388, 9479.357900282303, 9510.500927172621, 2625.291959627764, 9391.445313462109, 2445.464953324973, 2081.0826084762593, 1909.1883933764611, 2261.499097002599]
# recall: [0.8963399999999999, 0.90499, 0.88933, 0.90148, 0.98915, 0.90743, 0.9908399999999999, 0.9925299999999999, 0.99318, 0.99179]
# summary cols {'qps': [8392.23215264881, 7845.281323854443, 2334.7073588077005, 2116.114671322845, 2592.4817878579847, 1929.7849552873251, 8281.844080010718, 8466.757127132996, 8516.250666560283, 2862.027676103482], 'recall': [0.9014394869695731, 0.902643607586301, 0.9231000136444262, 0.9237754127438942, 0.9223222813480692, 0.9243075453677172, 0.9022069859462408, 0.8994542229499249, 0.9006344658207123, 0.9212034383954156], 'wspq': [0.06921649292763905, 0.07372070896438808, 0.23696204420794106, 0.2957147870105061, 0.2411330274252968, 0.3359516414244781, 0.07429948605994452, 0.06830066639377813, 0.05234679019420566, 0.2346472664756447], 'best_recall': (1929.7849552873251, 0.9243075453677172), 'best_qps': (0.9006344658207123, 8516.250666560283), 'best_wspq': (0.9006344658207123, 8516.250666560283, 0.05234679019420566), 'cost': 0}
# computing scores
# diff recall deep-1B 0.045760000000000134
# diff qps deep-1B 5751.610888444753
# diff power deep-1B 0
# diff recall bigann-1B 0.06552999999999987
# diff qps bigann-1B 7323.745927172621
# diff power bigann-1B 0
# diff recall text2image-1B 0.02429999999999999
# diff qps text2image-1B 844.262193017232
# diff power text2image-1B 0
# diff recall msturing-1B 0.06780599999999992
# diff qps msturing-1B 17618.043156063188
# diff power msturing-1B 0
# diff recall msspacev-1B 0.07430754536771722
# diff qps msspacev-1B 7032.033666560283
# diff power msspacev-1B 0
# summary {'deep-1B': [0.9877600000000001, 9174.083888444753, 0.040971066560000005, 0], 'bigann-1B': [0.9925299999999999, 9510.500927172621, 0.039696447040000006, 0], 'text2image-1B': [0.8843, 2354.886193017232, 0.27743859648, 0], 'msturing-1B': [0.977806, 20039.899156063188, 0.02312768002666667, 0], 'msspacev-1B': [0.9243075453677172, 8516.250666560283, 0.05234679019420566, 0], 'score': [0.27770354536771713, 38569.695831258075, 0, 0]}
#                  recall           qps     power  cost
# deep-1B        0.987760   9174.083888  0.040971     0
# bigann-1B      0.992530   9510.500927  0.039696     0
# text2image-1B  0.884300   2354.886193  0.277439     0
# msturing-1B    0.977806  20039.899156  0.023128     0
# msspacev-1B    0.924308   8516.250667  0.052347     0
# score          0.277704  38569.695831  0.000000     0
#                  recall           qps     power  cost
# deep-1B        0.987760   9174.083888  0.040971     0
# bigann-1B      0.992530   9510.500927  0.039696     0
# text2image-1B  0.884300   2354.886193  0.277439     0
# msturing-1B    0.977806  20039.899156  0.023128     0
# msspacev-1B    0.924308   8516.250667  0.052347     0
# score          0.277704  38569.695831  0.000000     0

# %%
# %matplotlib inline
evaluator.plot_recall("deep-1B", 
        zoom=[[1900,2600],[0.97, 0.99]], # provide zoom subplot extents
        tweak=[[2000,0],[0,-0.009]] # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_throughput("deep-1B", 
        zoom=[[0.87, 0.95],[8000,10000]], # provide zoom subplot extents
        tweak=[[-0.01,-2000],[-0.025,300]] # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_power("deep-1B", 
        tweak=[[0.0,0.1],[-5000,0.1]] # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_recall("bigann-1B", 
        zoom=[[1500,3000],[0.97, 1.0]], # provide zoom subplot extents
        tweak=[[2000,0],[0,-0.009]] # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_throughput("bigann-1B", 
        zoom=[[0.87, 0.95],[9000,10000]], # provide zoom subplot extents
        tweak=[[-0.01,-2000],[-0.025,300]] # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_power("bigann-1B", 
        tweak=[[0,0.1],[-5000,0.1]] # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_recall("text2image-1B", 
        zoom=[[1700,2500],[0.86, 0.90]], # provide zoom subplot extents
        tweak=[[-1000,0.01],[0,0.01]] # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_throughput("text2image-1B", 
        zoom=[[0.86,0.89],[1750, 2400]], # provide zoom subplot extents
        tweak=[[0.0,-700],[0.0,-80]] # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_power("text2image-1B", 
        tweak=[[0,0.1],[-1200,0.21]] # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_recall("msspacev-1B", 
        zoom=[[1500,3600],[0.92, 0.93]], # provide zoom subplot extents
        tweak=[[2000,0],[0,0.003]] # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_throughput("msspacev-1B", 
        zoom=[[0.87, 0.95],[8000,9000],], # provide zoom subplot extents
        tweak=[[0.005,-500],[-0.005,200]] # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_power("msspacev-1B", 
        tweak=[[0,0.05],[-4000,0.1]] # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_recall("msturing-1B", 
        zoom=[[1200,4000],[0.97, 0.99]], # provide zoom subplot extents
        tweak=[[2000,0],[0,0.005]] # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_throughput("msturing-1B", 
        zoom=[[0.88,0.94],[18000, 21000]], # provide zoom subplot extents
        tweak=[[-0.015,-6000],[-0.015,200]] # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_power("msturing-1B", 
        tweak=[[-0.01,0.1],[-12000,0.1]] # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_recall("bigann-1B", 
        zoom=[[1500,3000],[0.98, 1.0]], # provide zoom subplot extents
        tweak=[[2000,0],[0,-0.009]] # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_throughput("bigann-1B", 
        zoom=[[0.87,0.92],[9000, 10000]], # provide zoom subplot extents
        tweak=[[-0.01,-2000],[-0.020,100]] # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_power("bigann-1B", 
        tweak=[[0,0.1],[-5000,0.1]] # adjust text annotation
)

# %%
# %matplotlib inline
evaluator.plot_recall("ssnpp-1B", 
        zoom=[[1900,2600],[0.97, 0.99]], # provide zoom subplot extents
        tweak=[[2000,0],[0,-0.009]] # adjust text annotation
)
# Out:
# Submission did not qualify for this dataset.
# False

# %%
# %matplotlib inline
evaluator.plot_throughput("ssnpp-1B", 
        zoom=[[8000,10000],[0.87, 0.95]], # provide zoom subplot extents
        tweak=[[-0.01,-2000],[-0.025,300]] # adjust text annotation
)
# Out:
# Submission did not qualify for this dataset.
# False

# %%
# %matplotlib inline
evaluator.plot_power("ssnpp-1B", 
        tweak=[[0,0.1],[-5000,0.1]] # adjust text annotation
)
# Out:
# Submission did not qualify for this dataset.
# False
